# %% [markdown]
# # Teste do método de Newton utilizando a função Rosenbrock

# %% [markdown]
# Teste do algoritmo de otimização de Newton utilizando a função Rosenbrock. Esta é uma função não-convexa introduzida por Howard H. Rosenbrock em 1960.
#
# **[Referências]**
#
# https://en.wikipedia.org/wiki/Rosenbrock_function

# %% [markdown]
# ## Importando as bibliotecas

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Função Rosenbrock

# %% [markdown]
# A função Rosenbrock possui um mínimo global que é localizado em um longo e estreito vale de formato parabólico. Esta função é definida como:
#
# $$ f(x,y) = (a-x)^2 + b(y - x^2)^2, $$
#
# em que $(x,y) = (a,a^2)$ é o mínimo global desta função.

# %%
def rosenbrock(x,y):
    '''
    Defining the rosenbrock function.   
    
    '''
    f = (1. - x)**2 + 100.*(y - x**2)**2
    return f

# %% [markdown]
# ## Definindo as coordenadas para calcular a função

# %%
Nx = 30
Ny = 30
x = np.linspace(-5.,5.,num=Nx)
y = np.linspace(-10.,10.,num=Ny)

# %%
X,Y = np.meshgrid(x,y)

# %%
Z = rosenbrock(X,Y)

# %% [markdown]
# ## Visualizando a função Rosenbrock

# %%
title_font = 22
bottom_font = 16
plt.figure(figsize=(10,8))

plt.contourf(X, Y, Z, 100, cmap='viridis')
plt.plot(1.,1., 'y*',markersize=18)
plt.colorbar(pad=0.01, aspect=40, shrink=1.0)
plt.xlabel('x', fontsize = title_font)
plt.ylabel('y', fontsize = title_font)
plt.title('Rosenbrock Function',fontsize=20)

plt.show()

# %% [markdown]
# ## Calculando o gradiente e a Hessiana da função Rosenbrock

# %%
def gradient(x,y):
    '''
    Calculate the gradient of rosenbrock function.
    '''
    J1 = -400.*x*(y - x**2) - 2.*(1. - x)
    J2 = 200.*(y - x**2)
    J = np.array([J1,J2])
    return J

# %%
def hessian(x,y):
    '''
    Calculate the Hessian Matrix of rosenbrock function.
    '''    
    H11 = -400.*y + 1200.*x**2 + 2.
    H12 = -400.*x
    H21 = -400.*x
    H22 = 200.
    H = np.array([[H11,H12],[H21,H22]])
    return H

# %% [markdown]
# ## Resolvendo o sistema linear através do método de Newton

# %%
itmax = 20

px = []
py = []
p0 = np.array([-1.,-5]) # Chute inicial
px.append(p0[0])
py.append(p0[1])

phi = []
iteration = []
for i in range(itmax):
    phi_i = rosenbrock(p0[0],p0[1])
    
    J = gradient(p0[0],p0[1])
    H = hessian(p0[0],p0[1])
    dp = np.linalg.solve(H,-J)
        
    p0 += dp
    phi_plus = rosenbrock(p0[0],p0[1])
    
    iteration.append(i)
    px.append(p0[0])
    py.append(p0[1])
    phi.append(phi_plus)

# %% [markdown]
# ### Estimativa para o mínimo da função

# %%
p0
# Out:
# array([1., 1.])

# %%
itle_font = 22
bottom_font = 16
plt.figure(figsize=(10,8))

plt.contourf(X, Y, Z, 100, cmap='viridis')
plt.colorbar(pad=0.01, aspect=40, shrink=1.0)
plt.plot(1.,1., 'y*',markersize=18)
plt.plot(px,py,'wo-')
plt.xlabel('x', fontsize = title_font)
plt.ylabel('y', fontsize = title_font)
plt.title('Rosenbrock Function',fontsize=20)

plt.show()
