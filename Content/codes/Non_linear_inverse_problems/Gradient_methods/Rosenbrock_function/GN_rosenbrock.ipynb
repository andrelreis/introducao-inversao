# %% [markdown]
# # Teste do método de Gauss-Newton utilizando a função Rosenbrock

# %% [markdown]
# Teste do algoritmo de otimização de Gauss-Newton utilizando a função Rosenbrock. Esta é uma função não-convexa introduzida por Howard H. Rosenbrock em 1960.
#
# **[Referências]**
#
# https://en.wikipedia.org/wiki/Rosenbrock_function

# %% [markdown]
# ## Importando as bibliotecas

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Função Rosenbrock

# %% [markdown]
# A função Rosenbrock possui um mínimo global que é localizado em um longo e estreito vale de formato parabólico. Esta função é definida como:
#
# $$ f(x,y) = (a-x)^2 + b(y - x^2)^2, $$
#
# em que $(x,y) = (a,a^2)$ é o mínimo global desta função.

# %%
def rosenbrock(x,y):
    '''
    Defining the rosenbrock function.   
    
    '''
    f = (1. - x)**2 + 100.*(y - x**2)**2
    return f

# %% [markdown]
# ## Definindo as coordenadas para calcular a função

# %%
Nx = 30
Ny = 30
x = np.linspace(-5.,5.,num=Nx)
y = np.linspace(-10.,10.,num=Ny)

# %%
X,Y = np.meshgrid(x,y)

# %%
Z = rosenbrock(X,Y)

# %% [markdown]
# ## Visualizando a função Rosenbrock

# %%
title_font = 22
bottom_font = 16
plt.figure(figsize=(10,8))

plt.contourf(X, Y, Z, 100, cmap='viridis')
plt.plot(1.,1., 'y*',markersize=18)
plt.colorbar(pad=0.01, aspect=40, shrink=1.0)
plt.xlabel('x', fontsize = title_font)
plt.ylabel('y', fontsize = title_font)
plt.title('Rosenbrock Function',fontsize=20)

plt.show()

# %% [markdown]
# ## Calculando o gradiente

# %%
def residual(x,y):
    '''
    Calculate the residual of rosenbrock function.
    '''
    J1 = 10.*(y - x**2)
    J2 = (1. - x)
    r = np.array([J1,J2])
    return r

# %%
def sensitivity(x,y):
    '''
    Calculate the sensitivity matrix of rosenbrock function.
    '''
    A11 = -20.*x
    A12 = 10.
    A21 = -1.
    A22 = 0.
    A = np.array([[A11,A12],[A21,A22]])
    return A

# %% [markdown]
# ## Resolvendo o sistema linear através do método de Gauss-Newton

# %%
itmax = 20

px = []
py = []
p0 = np.array([-1.,-5.]) # Chute inicial
px.append(p0[0])
py.append(p0[1])

phi = []
iteration = []
for i in range(itmax):
    phi_i = rosenbrock(p0[0],p0[1])
    G = sensitivity(p0[0],p0[1])
    r = residual(p0[0],p0[1])
    J = -np.dot(G.T,r)
    H = np.dot(G.T,G)
    dp = np.linalg.solve(H,J)
        
    p0 += dp
    phi_plus = rosenbrock(p0[0],p0[1])
    
    iteration.append(i)
    px.append(p0[0])
    py.append(p0[1])
    phi.append(phi_plus)

# %% [markdown]
# ### Estimativa para o mínimo da função

# %%
p0
# Out:
# array([1., 1.])

# %%
title_font = 22
bottom_font = 16
plt.figure(figsize=(10,8))

plt.contourf(X, Y, Z, 100, cmap='viridis')
plt.colorbar(pad=0.01, aspect=40, shrink=1.0)
plt.plot(1.,1., 'y*',markersize=18)
plt.plot(px,py,'wo-')
plt.xlabel('x', fontsize = title_font)
plt.ylabel('y', fontsize = title_font)
plt.title('Rosenbrock Function',fontsize=20)

plt.show()
